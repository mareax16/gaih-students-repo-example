# %%
mylist= [1,2,3,4,5,6]
print(mylist)
mylist3= mylist[0:3]
mylist2= mylist[3:6]
print(mylist2)
print(mylist3)
mylist2.extend(mylist3)
print(mylist2)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]
# [1, 2, 3]
# [4, 5, 6, 1, 2, 3]

# %%
n= int(input('Please enter the your number'))
for i in range(n+1):
  if i %2==0:
    print(i)
# Out:
# Please enter the your number9
# 0
# 2
# 4
# 6
# 8
